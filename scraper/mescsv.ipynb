# %%
"C:\Users\lucie\Downloads\data_filtre.csv"
"C:\Users\lucie\OneDrive\Documents\projet\scraping\Data\rec.csv"

# %%
import pandas as pd

df1 = pd.read_csv(r"C:\Users\lucie\Downloads\data_filtre.csv")
df2 = pd.read_csv(r"C:\Users\lucie\OneDrive\Documents\projet\scraping\Data\rec.csv", sep=';')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4645 entries, 0 to 4644
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ﻿"Code SP+ de la structure"       4645 non-null   object
#  1   Intitulé du réseau                4645 non-null   object
#  2   Intitulé de la typologie          4645 non-null   object
#  3   Intitulé de la structure          4645 non-null   object
#  4   Intitulé structure usager         143 non-null    object
#  5   Description de la structure       3818 non-null   object
#  6   Identifiant de la structure       2395 non-null   object
#  7   Type d'identifiant                1785 non-null   object
#  8   Code SP+ structure parent         4618 non-null   object
#  9   Intitulé de la structure parente  4618 non-null   object
#  10  Adresse                           1945 non-null   object
# ...

# %%
df1
# Out:
#      ﻿"Code SP+ de la structure" Intitulé du réseau
# 0                     3Tn8gzTdcz   POLICE NATIONALE  \
# 1                     GYL05KOxWg   POLICE NATIONALE
# 2                     7VV7KUkiJY   POLICE NATIONALE
# 3                     r7qjlPvWjQ   POLICE NATIONALE
# 4                     Qon8GAOoum   POLICE NATIONALE
# ...                          ...                ...
# 4640                  AVqkdmtBkd              DGDDI
# 4641                  OpnJJVMIvZ              DGDDI
# 4642                  8AxKDzgabJ              DGDDI
# 4643                  VQ4uCvpAbh              DGDDI
# 4644                  d9ypPtXpKC    France services
#
#                               Intitulé de la typologie
# 0     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE  \
# 1     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE
# 2     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE
# 3     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE
# 4     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Adresse                   1 non-null      object
#  1   Intitulé du réseau        1 non-null      object
#  2   Intitulé de la typologie  1 non-null      object
#  3   Ville                     1 non-null      object
#  4   Intitulé de la structure  1 non-null      object
#  5   GM_search                 1 non-null      object
# dtypes: object(6)
# memory usage: 180.0+ bytes

# %%
df2
# Out:
#             Adresse             Intitulé du réseau Intitulé de la typologie
# 0  144 Rue de Bavay  Réseau des rectorats et DSDEN                 Rectorat  \
#
#    Ville         Intitulé de la structure
# 0  LILLE  RECTORAT DE L'ACADEMIE DE LILLE  \
#
#                                            GM_search
# 0  144 Rue de Bavay, Réseau des rectorats et DSDE...

# %%
kash = "Code SP+ de la structure"

# %%
df3 = df1.loc[:, ['Adresse', 'Intitulé du réseau', 'Intitulé de la typologie', 'Ville', 'Intitulé de la structure']]
df3['Code SP+'] = df1.iloc[:, 0]
df3
# Out:
#                           Adresse Intitulé du réseau
# 0           7 Place Mendes France   POLICE NATIONALE  \
# 1     9 Rue Brisout de Barneville   POLICE NATIONALE
# 2            2 Rue Antoine Becker   POLICE NATIONALE
# 3              19 Avenue de Paris   POLICE NATIONALE
# 4              6 Avenue d'Orléans   POLICE NATIONALE
# ...                           ...                ...
# 4640                          NaN              DGDDI
# 4641                          NaN              DGDDI
# 4642                          NaN              DGDDI
# 4643                          NaN              DGDDI
# 4644      22 rue François Monnier    France services
#
#                               Intitulé de la typologie       Ville
# 0     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE       LAVAL  \
# 1     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE       ROUEN
# 2     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE   MARSEILLE
# ...

# %%
df4 = df3.fillna('')
def concat_row(row):
    return ', '.join([str(x) for x in row[:-1]])

df4['GM_search'] = df4.apply(concat_row, axis=1)

df4
# Out:
#                           Adresse Intitulé du réseau
# 0           7 Place Mendes France   POLICE NATIONALE  \
# 1     9 Rue Brisout de Barneville   POLICE NATIONALE
# 2            2 Rue Antoine Becker   POLICE NATIONALE
# 3              19 Avenue de Paris   POLICE NATIONALE
# 4              6 Avenue d'Orléans   POLICE NATIONALE
# ...                           ...                ...
# 4640                                           DGDDI
# 4641                                           DGDDI
# 4642                                           DGDDI
# 4643                                           DGDDI
# 4644      22 rue François Monnier    France services
#
#                               Intitulé de la typologie       Ville
# 0     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE       LAVAL  \
# 1     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE       ROUEN
# 2     DIRECTION DEPARTEMENTALE DE LA SECURITE PUBLIQUE   MARSEILLE
# ...

# %%
df5 = df4[df4['Intitulé du réseau']=='POLE EMPLOI']
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277 entries, 14 to 4632
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Adresse                   277 non-null    object
#  1   Intitulé du réseau        277 non-null    object
#  2   Intitulé de la typologie  277 non-null    object
#  3   Ville                     277 non-null    object
#  4   Intitulé de la structure  277 non-null    object
#  5   Code SP+                  277 non-null    object
#  6   GM_search                 277 non-null    object
# dtypes: object(7)
# memory usage: 17.3+ KB

# %%
df5.to_csv(r"C:\Users\lucie\OneDrive\Documents\dependance\scraping\pole_emploi.csv", sep = ',')
