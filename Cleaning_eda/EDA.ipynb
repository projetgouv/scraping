# %%
import pandas as pd

# %%
import pandas as pd
cols = ('date', 'rate', 'review_text', 'object_name', 'object_address', 'overall_rating')
all_data = pd.read_csv('/Users/camille/repo/Hetic/projet_gouv/scraping/Data/scrape_paris.csv', usecols=cols)

# %%
all_data
# Out:
#                date  rate                                        review_text
# 0     il y a 3 mois     5  Agence totalmente désorganisée avec un fonctio...  \
# 1     il y a 5 mois     5  Toujours bien accueillie. Très bonne organisat...
# 2      il y a un an     5  Meilleur service client, rapide Employés servi...
# 3      il y a 2 ans     5  Bien loin des clichés, des gens efficaces, com...
# 4      il y a 2 ans     5   Une équipe qui fait son maximum pour vous aider.
# ...             ...   ...                                                ...
# 1022  il y a 2 mois     5                                                NaN
# 1023   il y a 6 ans     5                                                NaN
# 1024   il y a 2 ans     5                                                NaN
# 1025   il y a 7 ans     5                                                NaN
# 1026   il y a 2 ans     5                                                NaN
#
#       object_name                   object_address overall_rating
# 0     Pôle emploi  75 Av. Jean Jaurès, 75019 Paris            3,2
# 1     Pôle emploi  75 Av. Jean Jaurès, 75019 Paris            3,2
# 2     Pôle emploi  75 Av. Jean Jaurès, 75019 Paris            3,2
# 3     Pôle emploi  75 Av. Jean Jaurès, 75019 Paris            3,2
# 4     Pôle emploi  75 Av. Jean Jaurès, 75019 Paris            3,2
# ...           ...                              ...            ...
# 1022  Pôle emploi     10 Rue Brancion, 75015 Paris            2,8
# 1023  Pôle emploi     10 Rue Brancion, 75015 Paris            2,8
# 1024  Pôle emploi     10 Rue Brancion, 75015 Paris            2,8
# 1025  Pôle emploi     10 Rue Brancion, 75015 Paris            2,8
# 1026  Pôle emploi     10 Rue Brancion, 75015 Paris            2,8
#
# [1027 rows x 6 columns]

# %%
all_data['rate'].value_counts()
# Out:
# rate
# 5    1027
# Name: count, dtype: int64
